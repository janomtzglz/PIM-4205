# %% [markdown]
# # Using Numpy with figures

# %% [markdown]
# * import numpy

# %%
import numpy as np

# %% [markdown]
# * to work with figures

# %%
from skimage import io

# %%
photo=io.imread('wavehokusai.jpg')

# %%
from matplotlib import pyplot as plt

# %%
photo

# %%
plt.imshow(photo)

# %%
plt.imshow(photo[::-1]) # reverse the rows

# %%
plt.imshow(photo[:,::-1])

# %%
plt.imshow(photo[350:550,500:700]) # subgigure

# %% [markdown]
# Let's reduce the image

# %%
plt.imshow(photo[::2,::2])

# %% [markdown]
# ## How to import modules

# %% [markdown]
# 1.-

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.pyplot import*
