# %% [markdown]
# # Sensitivity and specificity

# %%
from IPython.display import Image

# %% [markdown]
# ## Types of error

# %% [markdown]
# * Type I errors are errors where the result is significant despite the fact that the null hypothesis is true

# %% [markdown]
# * Type II errors are errors where the result is not significant, despite the fact that the null hypothesis is false

# %% [markdown]
# ### Sensitivity

# %% [markdown]
# * Also called power. Proportion of positives that are correctly identified by a test (= probability of a positive test, given the patient is ill)

# %% [markdown]
# ### Specificity

# %% [markdown]
# * Proportion of negatives that are correctly identified by a test (= probability of a negative test, given that patient is well)

# %% [markdown]
# ### Positive Predictive Value (PPV)

# %% [markdown]
# * Proportion of patients with positive test results who are correctly diagnosed.

# %% [markdown]
# ### Negative Predictive Value (NPV)

# %% [markdown]
# * Proportion of patients with negative test results who are correctly diagnosed.

# %%
Image(filename = "hypothesis_tests_sensitivity_specificity_01.png")

# %% [markdown]
# #### Example
# Consider a test with: <br>
# * True positive TP = 25
# * False positive FP = 175
# * False negative FN = 10
# * True negative TN = 2000

# %% [markdown]
# <b>Compute</b>: Sensitivity, Specificity, Positive Predictive Value (PPV) and Negative Predictive Value (NPV)

# %%
Image(filename = "hypothesis_tests_sensitivity_specificity_03.png")
